# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
KEY = os.getenv("OPENAI_API_KEY")

# %%
llm = ChatOpenAI(open_api_key=KEY,model_name="gpt-4", temperature=0.5)
# Out:
# /var/folders/4k/z2n89trd7z16ztzyr9ccz5hw0000gn/T/ipykernel_31805/1591658609.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(open_api_key=KEY,model_name="gpt-4", temperature=0.5)
# WARNING! open_api_key is not default parameter.
#                     open_api_key was transferred to model_kwargs.
#                     Please confirm that open_api_key is what you intended.
